# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
for i in range (1,6):            # this loop will run from 1-5(5 times- one for every line) as 6 is excluding in range function 
    for j in range(1,i+1):       # as last value is ignored but we need all i value hemce +1    
                                 # this j loop will print your stars using i as an input for it so that stars will increase
        print("*",end ="")       # as by default print statement changes line ,hence use end command to counter it.
    print("\n")                  # for j loop to end and print "*" and chnage to next line fo the ith loop.
# Out:
# *
#
# **
#
# ***
#
# ****
#
# *****
